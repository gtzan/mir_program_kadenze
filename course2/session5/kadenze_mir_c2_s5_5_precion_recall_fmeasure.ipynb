# %% [markdown]
# # Precision, recall and f-measure
# ### George Tzanetakis, University of Victoria
#
# In this notebook we go over the terminology of retrieval metrics: precision, recall and f-measure and how they are used in a variety of Music Information Retrieval (MIR) tasks. We first examine their classic original use as measures for the effectiveness of text information retrieval systems. Then we explore how they are used for evaluating classification systems, auto-tagging systems, as well as systems that estimate time boundaries (such as beat tracking and structure segmentation).

# %% [markdown]
# ## Text Retrieval
#
# The original scenario for which retrieval metrics were proposed is topic-based text retrieval. Today we are all familiar with this concept from search engines. The idea is that the user submits a query and the text retrieval system returns a set of what the system thinks are relevant documents. To evaluate the system an expert rates each returned document as relevant or not.

# %%
import numpy as np 

# suppose that are query is beatles and we are interested in retrieving documents 
# about the corresponding insect species 
query = 'beatles'

# Let's say a set of 10 documents is returned - their exact representation is not important 
# and could be a bag-of-words representation, text, a list of keywords etc 

# an expert/user goes over these automatically retrieved documents and marks 
# them as relevant or not relevant. 
# The documents that are about the insects are marked with a 1 and the 
# ones that are not relevant (perhaps about the music group) are marked
# with a zero. 
retrieved = np.array([1,1,0,1,1,1,1,0,1,0])

# %% [markdown]
# Precision is defined as the number of relevant retrieved documents divded by the number of returned documents. So for our particular example the precision is 0.70 or 70%.

# %%
import numpy as np

def precision(retrieved):
    retrieved_relevant = np.count_nonzero(retrieved == 1)
    return (retrieved_relevant / len(retrieved))


print("Precision = %.2f\n" % (precision(retrieved)))
# Out:
# Precision = 0.70

# %% [markdown]
# Notice that we can improve the precision in this case by returning less items. For example the precision when returning the first two items is 1 or 100%.

# %%
less_retrieved = np.array([1,1])
print("Precision = %.2f\n" % (precision(retrieved)))
# Out:
# Precision = 0.70

# %% [markdown]
# Now suppose that in the set of documents we are considering there are 15 documents about beatles (the insect species). Our set of retrieved results only contains 7 of them and therefore the recall in this case is 7/15=0.47

# %%
def recall(retrieved, num_relevant):
    retrieved_relevant = np.count_nonzero(retrieved == 1)
    return (retrieved_relevant / num_relevant)

# %%
retrieved = np.array([1,1,0,1,1,1,1,0,1,0])
print("Recall = %.2f\n" % (recall(retrieved,15)))
# Out:
# Recall = 0.47

# %% [markdown]
# We can trivially increase recall by returning more items with the extreme cases of returning all documents as relevant at the expense of diminishing precision. Alternatively we can only return less and less document increasing precision at the expense of recall. An effective retrieval system should achieve both high precision and recall. The most common measure that balances these two metrics is the f1-score or f-measure defined as the
# harmonic mean of precision and recall.
#
# \begin{equation}
# F_{1} = 2 * \frac{precision * recall}{precision + recall}
# \end{equation}

# %%
def f1_score(precision, recall): 
    return 2 * ((precision * recall) / (precision+recall))

precision = 0.7 
recall = 0.47
f1 = f1_score(precision,recall)
print("F1 = %.2f\n" % f1)
# Out:
# F1 = 0.56

# %% [markdown]
# ## Binary Classification
#
# For a binary classification problem we can consider the set of predictions as the retrieved documents and the ground truth as the annotations of relevance. For example suppose that we have a music/speech classification system that predicts 100 instances and lets say that 50 of them are labeled as music and 50 of them are labeled as speech. A system that would predict everything as music would have high recall (i.e all music instances according to the ground truth would be predicted correctly) but 0.5 precision as half of the predicted instances
# (the ones labeled speech according to the ground truth) would not be correctly predicted. A system that predicted a single instance of music correctly as music and all the other instances as speech would have a precision of 1 but really bad recall 1/50. Notice that in any binary classification system that outputs a class probability we can trade precision and recall by adjusting the threhold for classification. F1-score is defined similarly as with text retrieval as the harmonic mean of precision and recall.
#
# Another way to view precision and recall is through the terminology used for binary classification problems in medical tests which is in terms of true positives (TP), true negatives (TN), false positives (FP) ad false negatives (FN). It is easy to see that using this terminology precision can be defined as:
#
# \begin{equation}
# Precision = \frac{TP}{TP+FP}
# \end{equation}
#
# \begin{equation}
# Recall = \frac{TP}{TP+FN}
# \end{equation}

# %% [markdown]
# ## Multi-class and multi-label classification
#
# For a multi-class classification problem with K classes we can not directly calculate retrieval metrics as described. There are three common approaches that are used. In macro-averaging the metrics are computed
# independetly for each class and then the average is taken (this means that each class is treated equally even
# though some classes might have more instances/support than others). A micro-average aggregates the contributions of each class and computes the metric overall which means that classes that are over-represented will effect the metrics more. Finally weighted average returns support-weighted metrics.
#
# In multi-label classification (auto-tagging) each instances can be assigned more than one label. The approach to calculating retrieval metrics is similar with macro-averaging meaning that retrieval metrics are calculated separately for each tag column and then averagedm and micro-averaging meaning that retrieval metrics are calculating over the entiure matrix of predictions.
#
# Let's look at a particular example from musical genre classification. First audio features are extracted for the GTZAN dataset.

# %%
import glob
import librosa
import numpy as np

fnames = glob.glob("/Users/georgetzanetakis/data/sound/genres/*/*.wav")

genres = ['classical', 'country', 'disco', 'hiphop', 'jazz', 'rock', 'blues', 'reggae', 'pop', 'metal']

# allocate matrix for audio features and target 
audio_features = np.zeros((len(fnames), 40))
target = np.zeros(len(fnames))

# compute the features 
for (i,fname) in enumerate(fnames): 
    #print("Processing %d %s" % (i, fname))
    for (label,genre) in enumerate(genres): 
        if genre in fname: 
            audio, srate = librosa.load(fname)
            mfcc_matrix = librosa.feature.mfcc(y=audio, sr=srate)
            mean_mfcc = np.mean(mfcc_matrix,axis=1)
            std_mfcc = np.std(mfcc_matrix, axis=1)
            audio_fvec = np.hstack([mean_mfcc, std_mfcc])
            audio_features[i] = audio_fvec
            target[i] = label

print(audio_features.shape)
# Out:
# Processing 0 /Users/georgetzanetakis/data/sound/genres/pop/pop.00027.wav
# Processing 1 /Users/georgetzanetakis/data/sound/genres/pop/pop.00033.wav
# Processing 2 /Users/georgetzanetakis/data/sound/genres/pop/pop.00032.wav
# Processing 3 /Users/georgetzanetakis/data/sound/genres/pop/pop.00026.wav
# Processing 4 /Users/georgetzanetakis/data/sound/genres/pop/pop.00030.wav
# Processing 5 /Users/georgetzanetakis/data/sound/genres/pop/pop.00024.wav
# Processing 6 /Users/georgetzanetakis/data/sound/genres/pop/pop.00018.wav
# Processing 7 /Users/georgetzanetakis/data/sound/genres/pop/pop.00019.wav
# Processing 8 /Users/georgetzanetakis/data/sound/genres/pop/pop.00025.wav
# Processing 9 /Users/georgetzanetakis/data/sound/genres/pop/pop.00031.wav
# Processing 10 /Users/georgetzanetakis/data/sound/genres/pop/pop.00009.wav
# Processing 11 /Users/georgetzanetakis/data/sound/genres/pop/pop.00035.wav
# Processing 12 /Users/georgetzanetakis/data/sound/genres/pop/pop.00021.wav
# Processing 13 /Users/georgetzanetakis/data/sound/genres/pop/pop.00020.wav
# Processing 14 /Users/georgetzanetakis/data/sound/genres/pop/pop.00034.wav
# Processing 15 /Users/georgetzanetakis/data/sound/genres/pop/pop.00008.wav
# Processing 16 /Users/georgetzanetakis/data/sound/genres/pop/pop.00022.wav
# Processing 17 /Users/georgetzanetakis/data/sound/genres/pop/pop.00036.wav
# Processing 18 /Users/georgetzanetakis/data/sound/genres/pop/pop.00037.wav
# Processing 19 /Users/georgetzanetakis/data/sound/genres/pop/pop.00023.wav
# Processing 20 /Users/georgetzanetakis/data/sound/genres/pop/pop.00044.wav
# Processing 21 /Users/georgetzanetakis/data/sound/genres/pop/pop.00050.wav
# Processing 22 /Users/georgetzanetakis/data/sound/genres/pop/pop.00078.wav
# Processing 23 /Users/georgetzanetakis/data/sound/genres/pop/pop.00087.wav
# Processing 24 /Users/georgetzanetakis/data/sound/genres/pop/pop.00093.wav
# Processing 25 /Users/georgetzanetakis/data/sound/genres/pop/pop.00092.wav
# Processing 26 /Users/georgetzanetakis/data/sound/genres/pop/pop.00086.wav
# Processing 27 /Users/georgetzanetakis/data/sound/genres/pop/pop.00079.wav
# Processing 28 /Users/georgetzanetakis/data/sound/genres/pop/pop.00051.wav
# Processing 29 /Users/georgetzanetakis/data/sound/genres/pop/pop.00045.wav
# Processing 30 /Users/georgetzanetakis/data/sound/genres/pop/pop.00053.wav
# Processing 31 /Users/georgetzanetakis/data/sound/genres/pop/pop.00047.wav
# Processing 32 /Users/georgetzanetakis/data/sound/genres/pop/pop.00090.wav
# Processing 33 /Users/georgetzanetakis/data/sound/genres/pop/pop.00084.wav
# Processing 34 /Users/georgetzanetakis/data/sound/genres/pop/pop.00085.wav
# Processing 35 /Users/georgetzanetakis/data/sound/genres/pop/pop.00091.wav
# Processing 36 /Users/georgetzanetakis/data/sound/genres/pop/pop.00046.wav
# Processing 37 /Users/georgetzanetakis/data/sound/genres/pop/pop.00052.wav
# Processing 38 /Users/georgetzanetakis/data/sound/genres/pop/pop.00056.wav
# Processing 39 /Users/georgetzanetakis/data/sound/genres/pop/pop.00042.wav
# Processing 40 /Users/georgetzanetakis/data/sound/genres/pop/pop.00095.wav
# Processing 41 /Users/georgetzanetakis/data/sound/genres/pop/pop.00081.wav
# Processing 42 /Users/georgetzanetakis/data/sound/genres/pop/pop.00080.wav
# Processing 43 /Users/georgetzanetakis/data/sound/genres/pop/pop.00094.wav
# Processing 44 /Users/georgetzanetakis/data/sound/genres/pop/pop.00043.wav
# Processing 45 /Users/georgetzanetakis/data/sound/genres/pop/pop.00057.wav
# Processing 46 /Users/georgetzanetakis/data/sound/genres/pop/pop.00069.wav
# Processing 47 /Users/georgetzanetakis/data/sound/genres/pop/pop.00041.wav
# Processing 48 /Users/georgetzanetakis/data/sound/genres/pop/pop.00055.wav
# Processing 49 /Users/georgetzanetakis/data/sound/genres/pop/pop.00082.wav
# Processing 50 /Users/georgetzanetakis/data/sound/genres/pop/pop.00096.wav
# Processing 51 /Users/georgetzanetakis/data/sound/genres/pop/pop.00097.wav
# Processing 52 /Users/georgetzanetakis/data/sound/genres/pop/pop.00083.wav
# Processing 53 /Users/georgetzanetakis/data/sound/genres/pop/pop.00054.wav
# Processing 54 /Users/georgetzanetakis/data/sound/genres/pop/pop.00040.wav
# Processing 55 /Users/georgetzanetakis/data/sound/genres/pop/pop.00068.wav
# Processing 56 /Users/georgetzanetakis/data/sound/genres/pop/pop.00065.wav
# Processing 57 /Users/georgetzanetakis/data/sound/genres/pop/pop.00071.wav
# Processing 58 /Users/georgetzanetakis/data/sound/genres/pop/pop.00059.wav
# Processing 59 /Users/georgetzanetakis/data/sound/genres/pop/pop.00058.wav
# Processing 60 /Users/georgetzanetakis/data/sound/genres/pop/pop.00070.wav
# Processing 61 /Users/georgetzanetakis/data/sound/genres/pop/pop.00064.wav
# Processing 62 /Users/georgetzanetakis/data/sound/genres/pop/pop.00072.wav
# Processing 63 /Users/georgetzanetakis/data/sound/genres/pop/pop.00066.wav
# Processing 64 /Users/georgetzanetakis/data/sound/genres/pop/pop.00099.wav
# Processing 65 /Users/georgetzanetakis/data/sound/genres/pop/pop.00098.wav
# Processing 66 /Users/georgetzanetakis/data/sound/genres/pop/pop.00067.wav
# Processing 67 /Users/georgetzanetakis/data/sound/genres/pop/pop.00073.wav
# Processing 68 /Users/georgetzanetakis/data/sound/genres/pop/pop.00077.wav
# Processing 69 /Users/georgetzanetakis/data/sound/genres/pop/pop.00063.wav
# Processing 70 /Users/georgetzanetakis/data/sound/genres/pop/pop.00088.wav
# Processing 71 /Users/georgetzanetakis/data/sound/genres/pop/pop.00089.wav
# Processing 72 /Users/georgetzanetakis/data/sound/genres/pop/pop.00062.wav
# Processing 73 /Users/georgetzanetakis/data/sound/genres/pop/pop.00076.wav
# Processing 74 /Users/georgetzanetakis/data/sound/genres/pop/pop.00048.wav
# Processing 75 /Users/georgetzanetakis/data/sound/genres/pop/pop.00060.wav
# Processing 76 /Users/georgetzanetakis/data/sound/genres/pop/pop.00074.wav
# Processing 77 /Users/georgetzanetakis/data/sound/genres/pop/pop.00075.wav
# Processing 78 /Users/georgetzanetakis/data/sound/genres/pop/pop.00061.wav
# Processing 79 /Users/georgetzanetakis/data/sound/genres/pop/pop.00049.wav
# Processing 80 /Users/georgetzanetakis/data/sound/genres/pop/pop.00006.wav
# Processing 81 /Users/georgetzanetakis/data/sound/genres/pop/pop.00012.wav
# Processing 82 /Users/georgetzanetakis/data/sound/genres/pop/pop.00013.wav
# Processing 83 /Users/georgetzanetakis/data/sound/genres/pop/pop.00007.wav
# Processing 84 /Users/georgetzanetakis/data/sound/genres/pop/pop.00011.wav
# Processing 85 /Users/georgetzanetakis/data/sound/genres/pop/pop.00005.wav
# Processing 86 /Users/georgetzanetakis/data/sound/genres/pop/pop.00039.wav
# Processing 87 /Users/georgetzanetakis/data/sound/genres/pop/pop.00038.wav
# Processing 88 /Users/georgetzanetakis/data/sound/genres/pop/pop.00004.wav
# Processing 89 /Users/georgetzanetakis/data/sound/genres/pop/pop.00010.wav
# Processing 90 /Users/georgetzanetakis/data/sound/genres/pop/pop.00028.wav
# Processing 91 /Users/georgetzanetakis/data/sound/genres/pop/pop.00014.wav
# Processing 92 /Users/georgetzanetakis/data/sound/genres/pop/pop.00000.wav
# Processing 93 /Users/georgetzanetakis/data/sound/genres/pop/pop.00001.wav
# Processing 94 /Users/georgetzanetakis/data/sound/genres/pop/pop.00015.wav
# Processing 95 /Users/georgetzanetakis/data/sound/genres/pop/pop.00029.wav
# Processing 96 /Users/georgetzanetakis/data/sound/genres/pop/pop.00003.wav
# Processing 97 /Users/georgetzanetakis/data/sound/genres/pop/pop.00017.wav
# Processing 98 /Users/georgetzanetakis/data/sound/genres/pop/pop.00016.wav
# Processing 99 /Users/georgetzanetakis/data/sound/genres/pop/pop.00002.wav
# Processing 100 /Users/georgetzanetakis/data/sound/genres/metal/metal.00022.wav
# Processing 101 /Users/georgetzanetakis/data/sound/genres/metal/metal.00036.wav
# Processing 102 /Users/georgetzanetakis/data/sound/genres/metal/metal.00037.wav
# Processing 103 /Users/georgetzanetakis/data/sound/genres/metal/metal.00023.wav
# Processing 104 /Users/georgetzanetakis/data/sound/genres/metal/metal.00009.wav
# Processing 105 /Users/georgetzanetakis/data/sound/genres/metal/metal.00035.wav
# Processing 106 /Users/georgetzanetakis/data/sound/genres/metal/metal.00021.wav
# Processing 107 /Users/georgetzanetakis/data/sound/genres/metal/metal.00020.wav
# Processing 108 /Users/georgetzanetakis/data/sound/genres/metal/metal.00034.wav
# Processing 109 /Users/georgetzanetakis/data/sound/genres/metal/metal.00008.wav
# Processing 110 /Users/georgetzanetakis/data/sound/genres/metal/metal.00030.wav
# Processing 111 /Users/georgetzanetakis/data/sound/genres/metal/metal.00024.wav
# Processing 112 /Users/georgetzanetakis/data/sound/genres/metal/metal.00018.wav
# Processing 113 /Users/georgetzanetakis/data/sound/genres/metal/metal.00019.wav
# Processing 114 /Users/georgetzanetakis/data/sound/genres/metal/metal.00025.wav
# Processing 115 /Users/georgetzanetakis/data/sound/genres/metal/metal.00031.wav
# Processing 116 /Users/georgetzanetakis/data/sound/genres/metal/metal.00027.wav
# Processing 117 /Users/georgetzanetakis/data/sound/genres/metal/metal.00033.wav
# Processing 118 /Users/georgetzanetakis/data/sound/genres/metal/metal.00032.wav
# Processing 119 /Users/georgetzanetakis/data/sound/genres/metal/metal.00026.wav
# Processing 120 /Users/georgetzanetakis/data/sound/genres/metal/metal.00082.wav
# Processing 121 /Users/georgetzanetakis/data/sound/genres/metal/metal.00096.wav
# Processing 122 /Users/georgetzanetakis/data/sound/genres/metal/metal.00069.wav
# Processing 123 /Users/georgetzanetakis/data/sound/genres/metal/metal.00041.wav
# Processing 124 /Users/georgetzanetakis/data/sound/genres/metal/metal.00055.wav
# Processing 125 /Users/georgetzanetakis/data/sound/genres/metal/metal.00054.wav
# Processing 126 /Users/georgetzanetakis/data/sound/genres/metal/metal.00040.wav
# Processing 127 /Users/georgetzanetakis/data/sound/genres/metal/metal.00068.wav
# Processing 128 /Users/georgetzanetakis/data/sound/genres/metal/metal.00097.wav
# Processing 129 /Users/georgetzanetakis/data/sound/genres/metal/metal.00083.wav
# Processing 130 /Users/georgetzanetakis/data/sound/genres/metal/metal.00095.wav
# Processing 131 /Users/georgetzanetakis/data/sound/genres/metal/metal.00081.wav
# Processing 132 /Users/georgetzanetakis/data/sound/genres/metal/metal.00056.wav
# Processing 133 /Users/georgetzanetakis/data/sound/genres/metal/metal.00042.wav
# Processing 134 /Users/georgetzanetakis/data/sound/genres/metal/metal.00043.wav
# Processing 135 /Users/georgetzanetakis/data/sound/genres/metal/metal.00057.wav
# Processing 136 /Users/georgetzanetakis/data/sound/genres/metal/metal.00080.wav
# Processing 137 /Users/georgetzanetakis/data/sound/genres/metal/metal.00094.wav
# Processing 138 /Users/georgetzanetakis/data/sound/genres/metal/metal.00090.wav
# Processing 139 /Users/georgetzanetakis/data/sound/genres/metal/metal.00084.wav
# Processing 140 /Users/georgetzanetakis/data/sound/genres/metal/metal.00053.wav
# Processing 141 /Users/georgetzanetakis/data/sound/genres/metal/metal.00047.wav
# Processing 142 /Users/georgetzanetakis/data/sound/genres/metal/metal.00046.wav
# Processing 143 /Users/georgetzanetakis/data/sound/genres/metal/metal.00052.wav
# Processing 144 /Users/georgetzanetakis/data/sound/genres/metal/metal.00085.wav
# Processing 145 /Users/georgetzanetakis/data/sound/genres/metal/metal.00091.wav
# Processing 146 /Users/georgetzanetakis/data/sound/genres/metal/metal.00087.wav
# Processing 147 /Users/georgetzanetakis/data/sound/genres/metal/metal.00093.wav
# Processing 148 /Users/georgetzanetakis/data/sound/genres/metal/metal.00044.wav
# Processing 149 /Users/georgetzanetakis/data/sound/genres/metal/metal.00050.wav
# Processing 150 /Users/georgetzanetakis/data/sound/genres/metal/metal.00078.wav
# Processing 151 /Users/georgetzanetakis/data/sound/genres/metal/metal.00079.wav
# Processing 152 /Users/georgetzanetakis/data/sound/genres/metal/metal.00051.wav
# Processing 153 /Users/georgetzanetakis/data/sound/genres/metal/metal.00045.wav
# Processing 154 /Users/georgetzanetakis/data/sound/genres/metal/metal.00092.wav
# Processing 155 /Users/georgetzanetakis/data/sound/genres/metal/metal.00086.wav
# Processing 156 /Users/georgetzanetakis/data/sound/genres/metal/metal.00048.wav
# Processing 157 /Users/georgetzanetakis/data/sound/genres/metal/metal.00060.wav
# Processing 158 /Users/georgetzanetakis/data/sound/genres/metal/metal.00074.wav
# Processing 159 /Users/georgetzanetakis/data/sound/genres/metal/metal.00075.wav
# Processing 160 /Users/georgetzanetakis/data/sound/genres/metal/metal.00061.wav
# Processing 161 /Users/georgetzanetakis/data/sound/genres/metal/metal.00049.wav
# Processing 162 /Users/georgetzanetakis/data/sound/genres/metal/metal.00088.wav
# Processing 163 /Users/georgetzanetakis/data/sound/genres/metal/metal.00077.wav
# Processing 164 /Users/georgetzanetakis/data/sound/genres/metal/metal.00063.wav
# Processing 165 /Users/georgetzanetakis/data/sound/genres/metal/metal.00062.wav
# Processing 166 /Users/georgetzanetakis/data/sound/genres/metal/metal.00076.wav
# Processing 167 /Users/georgetzanetakis/data/sound/genres/metal/metal.00089.wav
# Processing 168 /Users/georgetzanetakis/data/sound/genres/metal/metal.00099.wav
# Processing 169 /Users/georgetzanetakis/data/sound/genres/metal/metal.00072.wav
# Processing 170 /Users/georgetzanetakis/data/sound/genres/metal/metal.00066.wav
# Processing 171 /Users/georgetzanetakis/data/sound/genres/metal/metal.00067.wav
# Processing 172 /Users/georgetzanetakis/data/sound/genres/metal/metal.00073.wav
# Processing 173 /Users/georgetzanetakis/data/sound/genres/metal/metal.00098.wav
# Processing 174 /Users/georgetzanetakis/data/sound/genres/metal/metal.00065.wav
# Processing 175 /Users/georgetzanetakis/data/sound/genres/metal/metal.00071.wav
# Processing 176 /Users/georgetzanetakis/data/sound/genres/metal/metal.00059.wav
# Processing 177 /Users/georgetzanetakis/data/sound/genres/metal/metal.00058.wav
# Processing 178 /Users/georgetzanetakis/data/sound/genres/metal/metal.00070.wav
# Processing 179 /Users/georgetzanetakis/data/sound/genres/metal/metal.00064.wav
# Processing 180 /Users/georgetzanetakis/data/sound/genres/metal/metal.00003.wav
# Processing 181 /Users/georgetzanetakis/data/sound/genres/metal/metal.00017.wav
# Processing 182 /Users/georgetzanetakis/data/sound/genres/metal/metal.00016.wav
# Processing 183 /Users/georgetzanetakis/data/sound/genres/metal/metal.00002.wav
# Processing 184 /Users/georgetzanetakis/data/sound/genres/metal/metal.00028.wav
# Processing 185 /Users/georgetzanetakis/data/sound/genres/metal/metal.00014.wav
# Processing 186 /Users/georgetzanetakis/data/sound/genres/metal/metal.00000.wav
# Processing 187 /Users/georgetzanetakis/data/sound/genres/metal/metal.00001.wav
# Processing 188 /Users/georgetzanetakis/data/sound/genres/metal/metal.00015.wav
# Processing 189 /Users/georgetzanetakis/data/sound/genres/metal/metal.00029.wav
# Processing 190 /Users/georgetzanetakis/data/sound/genres/metal/metal.00011.wav
# Processing 191 /Users/georgetzanetakis/data/sound/genres/metal/metal.00005.wav
# Processing 192 /Users/georgetzanetakis/data/sound/genres/metal/metal.00039.wav
# Processing 193 /Users/georgetzanetakis/data/sound/genres/metal/metal.00038.wav
# Processing 194 /Users/georgetzanetakis/data/sound/genres/metal/metal.00004.wav
# Processing 195 /Users/georgetzanetakis/data/sound/genres/metal/metal.00010.wav
# Processing 196 /Users/georgetzanetakis/data/sound/genres/metal/metal.00006.wav
# Processing 197 /Users/georgetzanetakis/data/sound/genres/metal/metal.00012.wav
# Processing 198 /Users/georgetzanetakis/data/sound/genres/metal/metal.00013.wav
# Processing 199 /Users/georgetzanetakis/data/sound/genres/metal/metal.00007.wav
# Processing 200 /Users/georgetzanetakis/data/sound/genres/disco/disco.00052.wav
# Processing 201 /Users/georgetzanetakis/data/sound/genres/disco/disco.00046.wav
# Processing 202 /Users/georgetzanetakis/data/sound/genres/disco/disco.00091.wav
# Processing 203 /Users/georgetzanetakis/data/sound/genres/disco/disco.00085.wav
# Processing 204 /Users/georgetzanetakis/data/sound/genres/disco/disco.00084.wav
# Processing 205 /Users/georgetzanetakis/data/sound/genres/disco/disco.00090.wav
# Processing 206 /Users/georgetzanetakis/data/sound/genres/disco/disco.00047.wav
# Processing 207 /Users/georgetzanetakis/data/sound/genres/disco/disco.00053.wav
# Processing 208 /Users/georgetzanetakis/data/sound/genres/disco/disco.00045.wav
# Processing 209 /Users/georgetzanetakis/data/sound/genres/disco/disco.00051.wav
# Processing 210 /Users/georgetzanetakis/data/sound/genres/disco/disco.00079.wav
# Processing 211 /Users/georgetzanetakis/data/sound/genres/disco/disco.00086.wav
# Processing 212 /Users/georgetzanetakis/data/sound/genres/disco/disco.00092.wav
# Processing 213 /Users/georgetzanetakis/data/sound/genres/disco/disco.00093.wav
# Processing 214 /Users/georgetzanetakis/data/sound/genres/disco/disco.00087.wav
# Processing 215 /Users/georgetzanetakis/data/sound/genres/disco/disco.00078.wav
# Processing 216 /Users/georgetzanetakis/data/sound/genres/disco/disco.00050.wav
# Processing 217 /Users/georgetzanetakis/data/sound/genres/disco/disco.00044.wav
# Processing 218 /Users/georgetzanetakis/data/sound/genres/disco/disco.00068.wav
# Processing 219 /Users/georgetzanetakis/data/sound/genres/disco/disco.00040.wav
# Processing 220 /Users/georgetzanetakis/data/sound/genres/disco/disco.00054.wav
# Processing 221 /Users/georgetzanetakis/data/sound/genres/disco/disco.00083.wav
# Processing 222 /Users/georgetzanetakis/data/sound/genres/disco/disco.00097.wav
# Processing 223 /Users/georgetzanetakis/data/sound/genres/disco/disco.00096.wav
# Processing 224 /Users/georgetzanetakis/data/sound/genres/disco/disco.00082.wav
# Processing 225 /Users/georgetzanetakis/data/sound/genres/disco/disco.00055.wav
# Processing 226 /Users/georgetzanetakis/data/sound/genres/disco/disco.00041.wav
# Processing 227 /Users/georgetzanetakis/data/sound/genres/disco/disco.00069.wav
# Processing 228 /Users/georgetzanetakis/data/sound/genres/disco/disco.00057.wav
# Processing 229 /Users/georgetzanetakis/data/sound/genres/disco/disco.00043.wav
# Processing 230 /Users/georgetzanetakis/data/sound/genres/disco/disco.00094.wav
# Processing 231 /Users/georgetzanetakis/data/sound/genres/disco/disco.00080.wav
# Processing 232 /Users/georgetzanetakis/data/sound/genres/disco/disco.00081.wav
# Processing 233 /Users/georgetzanetakis/data/sound/genres/disco/disco.00095.wav
# Processing 234 /Users/georgetzanetakis/data/sound/genres/disco/disco.00042.wav
# Processing 235 /Users/georgetzanetakis/data/sound/genres/disco/disco.00056.wav
# Processing 236 /Users/georgetzanetakis/data/sound/genres/disco/disco.00031.wav
# Processing 237 /Users/georgetzanetakis/data/sound/genres/disco/disco.00025.wav
# Processing 238 /Users/georgetzanetakis/data/sound/genres/disco/disco.00019.wav
# Processing 239 /Users/georgetzanetakis/data/sound/genres/disco/disco.00018.wav
# Processing 240 /Users/georgetzanetakis/data/sound/genres/disco/disco.00024.wav
# Processing 241 /Users/georgetzanetakis/data/sound/genres/disco/disco.00030.wav
# Processing 242 /Users/georgetzanetakis/data/sound/genres/disco/disco.00026.wav
# Processing 243 /Users/georgetzanetakis/data/sound/genres/disco/disco.00032.wav
# Processing 244 /Users/georgetzanetakis/data/sound/genres/disco/disco.00033.wav
# Processing 245 /Users/georgetzanetakis/data/sound/genres/disco/disco.00027.wav
# Processing 246 /Users/georgetzanetakis/data/sound/genres/disco/disco.00023.wav
# Processing 247 /Users/georgetzanetakis/data/sound/genres/disco/disco.00037.wav
# Processing 248 /Users/georgetzanetakis/data/sound/genres/disco/disco.00036.wav
# Processing 249 /Users/georgetzanetakis/data/sound/genres/disco/disco.00022.wav
# Processing 250 /Users/georgetzanetakis/data/sound/genres/disco/disco.00008.wav
# Processing 251 /Users/georgetzanetakis/data/sound/genres/disco/disco.00034.wav
# Processing 252 /Users/georgetzanetakis/data/sound/genres/disco/disco.00020.wav
# Processing 253 /Users/georgetzanetakis/data/sound/genres/disco/disco.00021.wav
# Processing 254 /Users/georgetzanetakis/data/sound/genres/disco/disco.00035.wav
# Processing 255 /Users/georgetzanetakis/data/sound/genres/disco/disco.00009.wav
# Processing 256 /Users/georgetzanetakis/data/sound/genres/disco/disco.00010.wav
# Processing 257 /Users/georgetzanetakis/data/sound/genres/disco/disco.00004.wav
# Processing 258 /Users/georgetzanetakis/data/sound/genres/disco/disco.00038.wav
# Processing 259 /Users/georgetzanetakis/data/sound/genres/disco/disco.00039.wav
# Processing 260 /Users/georgetzanetakis/data/sound/genres/disco/disco.00005.wav
# Processing 261 /Users/georgetzanetakis/data/sound/genres/disco/disco.00011.wav
# Processing 262 /Users/georgetzanetakis/data/sound/genres/disco/disco.00007.wav
# Processing 263 /Users/georgetzanetakis/data/sound/genres/disco/disco.00013.wav
# Processing 264 /Users/georgetzanetakis/data/sound/genres/disco/disco.00012.wav
# Processing 265 /Users/georgetzanetakis/data/sound/genres/disco/disco.00006.wav
# Processing 266 /Users/georgetzanetakis/data/sound/genres/disco/disco.00002.wav
# Processing 267 /Users/georgetzanetakis/data/sound/genres/disco/disco.00016.wav
# Processing 268 /Users/georgetzanetakis/data/sound/genres/disco/disco.00017.wav
# Processing 269 /Users/georgetzanetakis/data/sound/genres/disco/disco.00003.wav
# Processing 270 /Users/georgetzanetakis/data/sound/genres/disco/disco.00029.wav
# Processing 271 /Users/georgetzanetakis/data/sound/genres/disco/disco.00015.wav
# Processing 272 /Users/georgetzanetakis/data/sound/genres/disco/disco.00001.wav
# Processing 273 /Users/georgetzanetakis/data/sound/genres/disco/disco.00000.wav
# Processing 274 /Users/georgetzanetakis/data/sound/genres/disco/disco.00014.wav
# Processing 275 /Users/georgetzanetakis/data/sound/genres/disco/disco.00028.wav
# Processing 276 /Users/georgetzanetakis/data/sound/genres/disco/disco.00073.wav
# Processing 277 /Users/georgetzanetakis/data/sound/genres/disco/disco.00067.wav
# Processing 278 /Users/georgetzanetakis/data/sound/genres/disco/disco.00098.wav
# Processing 279 /Users/georgetzanetakis/data/sound/genres/disco/disco.00099.wav
# Processing 280 /Users/georgetzanetakis/data/sound/genres/disco/disco.00066.wav
# Processing 281 /Users/georgetzanetakis/data/sound/genres/disco/disco.00072.wav
# Processing 282 /Users/georgetzanetakis/data/sound/genres/disco/disco.00064.wav
# Processing 283 /Users/georgetzanetakis/data/sound/genres/disco/disco.00070.wav
# Processing 284 /Users/georgetzanetakis/data/sound/genres/disco/disco.00058.wav
# Processing 285 /Users/georgetzanetakis/data/sound/genres/disco/disco.00059.wav
# Processing 286 /Users/georgetzanetakis/data/sound/genres/disco/disco.00071.wav
# Processing 287 /Users/georgetzanetakis/data/sound/genres/disco/disco.00065.wav
# Processing 288 /Users/georgetzanetakis/data/sound/genres/disco/disco.00049.wav
# Processing 289 /Users/georgetzanetakis/data/sound/genres/disco/disco.00061.wav
# Processing 290 /Users/georgetzanetakis/data/sound/genres/disco/disco.00075.wav
# Processing 291 /Users/georgetzanetakis/data/sound/genres/disco/disco.00074.wav
# Processing 292 /Users/georgetzanetakis/data/sound/genres/disco/disco.00060.wav
# Processing 293 /Users/georgetzanetakis/data/sound/genres/disco/disco.00048.wav
# Processing 294 /Users/georgetzanetakis/data/sound/genres/disco/disco.00076.wav
# Processing 295 /Users/georgetzanetakis/data/sound/genres/disco/disco.00062.wav
# Processing 296 /Users/georgetzanetakis/data/sound/genres/disco/disco.00089.wav
# Processing 297 /Users/georgetzanetakis/data/sound/genres/disco/disco.00088.wav
# Processing 298 /Users/georgetzanetakis/data/sound/genres/disco/disco.00063.wav
# Processing 299 /Users/georgetzanetakis/data/sound/genres/disco/disco.00077.wav
# Processing 300 /Users/georgetzanetakis/data/sound/genres/blues/blues.00093.wav
# Processing 301 /Users/georgetzanetakis/data/sound/genres/blues/blues.00087.wav
# Processing 302 /Users/georgetzanetakis/data/sound/genres/blues/blues.00050.wav
# Processing 303 /Users/georgetzanetakis/data/sound/genres/blues/blues.00044.wav
# Processing 304 /Users/georgetzanetakis/data/sound/genres/blues/blues.00078.wav
# Processing 305 /Users/georgetzanetakis/data/sound/genres/blues/blues.00079.wav
# Processing 306 /Users/georgetzanetakis/data/sound/genres/blues/blues.00045.wav
# Processing 307 /Users/georgetzanetakis/data/sound/genres/blues/blues.00051.wav
# Processing 308 /Users/georgetzanetakis/data/sound/genres/blues/blues.00086.wav
# Processing 309 /Users/georgetzanetakis/data/sound/genres/blues/blues.00092.wav
# Processing 310 /Users/georgetzanetakis/data/sound/genres/blues/blues.00084.wav
# Processing 311 /Users/georgetzanetakis/data/sound/genres/blues/blues.00090.wav
# Processing 312 /Users/georgetzanetakis/data/sound/genres/blues/blues.00047.wav
# Processing 313 /Users/georgetzanetakis/data/sound/genres/blues/blues.00053.wav
# Processing 314 /Users/georgetzanetakis/data/sound/genres/blues/blues.00052.wav
# Processing 315 /Users/georgetzanetakis/data/sound/genres/blues/blues.00046.wav
# Processing 316 /Users/georgetzanetakis/data/sound/genres/blues/blues.00091.wav
# Processing 317 /Users/georgetzanetakis/data/sound/genres/blues/blues.00085.wav
# Processing 318 /Users/georgetzanetakis/data/sound/genres/blues/blues.00081.wav
# Processing 319 /Users/georgetzanetakis/data/sound/genres/blues/blues.00095.wav
# Processing 320 /Users/georgetzanetakis/data/sound/genres/blues/blues.00042.wav
# Processing 321 /Users/georgetzanetakis/data/sound/genres/blues/blues.00056.wav
# Processing 322 /Users/georgetzanetakis/data/sound/genres/blues/blues.00057.wav
# Processing 323 /Users/georgetzanetakis/data/sound/genres/blues/blues.00043.wav
# Processing 324 /Users/georgetzanetakis/data/sound/genres/blues/blues.00094.wav
# Processing 325 /Users/georgetzanetakis/data/sound/genres/blues/blues.00080.wav
# Processing 326 /Users/georgetzanetakis/data/sound/genres/blues/blues.00096.wav
# Processing 327 /Users/georgetzanetakis/data/sound/genres/blues/blues.00082.wav
# Processing 328 /Users/georgetzanetakis/data/sound/genres/blues/blues.00069.wav
# Processing 329 /Users/georgetzanetakis/data/sound/genres/blues/blues.00055.wav
# Processing 330 /Users/georgetzanetakis/data/sound/genres/blues/blues.00041.wav
# Processing 331 /Users/georgetzanetakis/data/sound/genres/blues/blues.00040.wav
# Processing 332 /Users/georgetzanetakis/data/sound/genres/blues/blues.00054.wav
# Processing 333 /Users/georgetzanetakis/data/sound/genres/blues/blues.00068.wav
# Processing 334 /Users/georgetzanetakis/data/sound/genres/blues/blues.00083.wav
# Processing 335 /Users/georgetzanetakis/data/sound/genres/blues/blues.00097.wav
# Processing 336 /Users/georgetzanetakis/data/sound/genres/blues/blues.00033.wav
# Processing 337 /Users/georgetzanetakis/data/sound/genres/blues/blues.00027.wav
# Processing 338 /Users/georgetzanetakis/data/sound/genres/blues/blues.00026.wav
# Processing 339 /Users/georgetzanetakis/data/sound/genres/blues/blues.00032.wav
# Processing 340 /Users/georgetzanetakis/data/sound/genres/blues/blues.00024.wav
# Processing 341 /Users/georgetzanetakis/data/sound/genres/blues/blues.00030.wav
# Processing 342 /Users/georgetzanetakis/data/sound/genres/blues/blues.00018.wav
# Processing 343 /Users/georgetzanetakis/data/sound/genres/blues/blues.00019.wav
# Processing 344 /Users/georgetzanetakis/data/sound/genres/blues/blues.00031.wav
# Processing 345 /Users/georgetzanetakis/data/sound/genres/blues/blues.00025.wav
# Processing 346 /Users/georgetzanetakis/data/sound/genres/blues/blues.00009.wav
# Processing 347 /Users/georgetzanetakis/data/sound/genres/blues/blues.00021.wav
# Processing 348 /Users/georgetzanetakis/data/sound/genres/blues/blues.00035.wav
# Processing 349 /Users/georgetzanetakis/data/sound/genres/blues/blues.00034.wav
# Processing 350 /Users/georgetzanetakis/data/sound/genres/blues/blues.00020.wav
# Processing 351 /Users/georgetzanetakis/data/sound/genres/blues/blues.00008.wav
# Processing 352 /Users/georgetzanetakis/data/sound/genres/blues/blues.00036.wav
# Processing 353 /Users/georgetzanetakis/data/sound/genres/blues/blues.00022.wav
# Processing 354 /Users/georgetzanetakis/data/sound/genres/blues/blues.00023.wav
# Processing 355 /Users/georgetzanetakis/data/sound/genres/blues/blues.00037.wav
# Processing 356 /Users/georgetzanetakis/data/sound/genres/blues/blues.00012.wav
# Processing 357 /Users/georgetzanetakis/data/sound/genres/blues/blues.00006.wav
# Processing 358 /Users/georgetzanetakis/data/sound/genres/blues/blues.00007.wav
# Processing 359 /Users/georgetzanetakis/data/sound/genres/blues/blues.00013.wav
# Processing 360 /Users/georgetzanetakis/data/sound/genres/blues/blues.00005.wav
# Processing 361 /Users/georgetzanetakis/data/sound/genres/blues/blues.00011.wav
# Processing 362 /Users/georgetzanetakis/data/sound/genres/blues/blues.00039.wav
# Processing 363 /Users/georgetzanetakis/data/sound/genres/blues/blues.00038.wav
# Processing 364 /Users/georgetzanetakis/data/sound/genres/blues/blues.00010.wav
# Processing 365 /Users/georgetzanetakis/data/sound/genres/blues/blues.00004.wav
# Processing 366 /Users/georgetzanetakis/data/sound/genres/blues/blues.00028.wav
# Processing 367 /Users/georgetzanetakis/data/sound/genres/blues/blues.00000.wav
# Processing 368 /Users/georgetzanetakis/data/sound/genres/blues/blues.00014.wav
# Processing 369 /Users/georgetzanetakis/data/sound/genres/blues/blues.00015.wav
# Processing 370 /Users/georgetzanetakis/data/sound/genres/blues/blues.00001.wav
# Processing 371 /Users/georgetzanetakis/data/sound/genres/blues/blues.00029.wav
# Processing 372 /Users/georgetzanetakis/data/sound/genres/blues/blues.00017.wav
# Processing 373 /Users/georgetzanetakis/data/sound/genres/blues/blues.00003.wav
# Processing 374 /Users/georgetzanetakis/data/sound/genres/blues/blues.00002.wav
# Processing 375 /Users/georgetzanetakis/data/sound/genres/blues/blues.00016.wav
# Processing 376 /Users/georgetzanetakis/data/sound/genres/blues/blues.00071.wav
# Processing 377 /Users/georgetzanetakis/data/sound/genres/blues/blues.00065.wav
# Processing 378 /Users/georgetzanetakis/data/sound/genres/blues/blues.00059.wav
# Processing 379 /Users/georgetzanetakis/data/sound/genres/blues/blues.00058.wav
# Processing 380 /Users/georgetzanetakis/data/sound/genres/blues/blues.00064.wav
# Processing 381 /Users/georgetzanetakis/data/sound/genres/blues/blues.00070.wav
# Processing 382 /Users/georgetzanetakis/data/sound/genres/blues/blues.00099.wav
# Processing 383 /Users/georgetzanetakis/data/sound/genres/blues/blues.00066.wav
# Processing 384 /Users/georgetzanetakis/data/sound/genres/blues/blues.00072.wav
# Processing 385 /Users/georgetzanetakis/data/sound/genres/blues/blues.00073.wav
# Processing 386 /Users/georgetzanetakis/data/sound/genres/blues/blues.00067.wav
# Processing 387 /Users/georgetzanetakis/data/sound/genres/blues/blues.00098.wav
# Processing 388 /Users/georgetzanetakis/data/sound/genres/blues/blues.00088.wav
# Processing 389 /Users/georgetzanetakis/data/sound/genres/blues/blues.00063.wav
# Processing 390 /Users/georgetzanetakis/data/sound/genres/blues/blues.00077.wav
# Processing 391 /Users/georgetzanetakis/data/sound/genres/blues/blues.00076.wav
# Processing 392 /Users/georgetzanetakis/data/sound/genres/blues/blues.00062.wav
# Processing 393 /Users/georgetzanetakis/data/sound/genres/blues/blues.00089.wav
# Processing 394 /Users/georgetzanetakis/data/sound/genres/blues/blues.00048.wav
# Processing 395 /Users/georgetzanetakis/data/sound/genres/blues/blues.00074.wav
# Processing 396 /Users/georgetzanetakis/data/sound/genres/blues/blues.00060.wav
# Processing 397 /Users/georgetzanetakis/data/sound/genres/blues/blues.00061.wav
# Processing 398 /Users/georgetzanetakis/data/sound/genres/blues/blues.00075.wav
# Processing 399 /Users/georgetzanetakis/data/sound/genres/blues/blues.00049.wav
# Processing 400 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00080.wav
# Processing 401 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00094.wav
# Processing 402 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00043.wav
# Processing 403 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00057.wav
# Processing 404 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00056.wav
# Processing 405 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00042.wav
# Processing 406 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00095.wav
# Processing 407 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00081.wav
# Processing 408 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00097.wav
# Processing 409 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00083.wav
# Processing 410 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00054.wav
# Processing 411 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00040.wav
# Processing 412 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00068.wav
# Processing 413 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00069.wav
# Processing 414 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00041.wav
# Processing 415 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00055.wav
# Processing 416 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00082.wav
# Processing 417 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00096.wav
# Processing 418 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00092.wav
# Processing 419 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00086.wav
# Processing 420 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00079.wav
# Processing 421 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00051.wav
# Processing 422 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00045.wav
# Processing 423 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00044.wav
# Processing 424 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00050.wav
# Processing 425 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00078.wav
# Processing 426 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00087.wav
# Processing 427 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00093.wav
# Processing 428 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00085.wav
# Processing 429 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00091.wav
# Processing 430 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00046.wav
# Processing 431 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00052.wav
# Processing 432 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00053.wav
# Processing 433 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00047.wav
# Processing 434 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00090.wav
# Processing 435 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00084.wav
# Processing 436 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00020.wav
# Processing 437 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00034.wav
# Processing 438 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00008.wav
# Processing 439 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00009.wav
# Processing 440 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00035.wav
# Processing 441 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00021.wav
# Processing 442 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00037.wav
# Processing 443 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00023.wav
# Processing 444 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00022.wav
# Processing 445 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00036.wav
# Processing 446 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00032.wav
# Processing 447 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00026.wav
# Processing 448 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00027.wav
# Processing 449 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00033.wav
# Processing 450 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00019.wav
# Processing 451 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00025.wav
# Processing 452 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00031.wav
# Processing 453 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00030.wav
# Processing 454 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00024.wav
# Processing 455 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00018.wav
# Processing 456 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00001.wav
# Processing 457 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00015.wav
# Processing 458 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00029.wav
# Processing 459 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00028.wav
# Processing 460 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00014.wav
# Processing 461 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00000.wav
# Processing 462 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00016.wav
# Processing 463 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00002.wav
# Processing 464 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00003.wav
# Processing 465 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00017.wav
# Processing 466 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00013.wav
# Processing 467 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00007.wav
# Processing 468 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00006.wav
# Processing 469 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00012.wav
# Processing 470 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00038.wav
# Processing 471 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00004.wav
# Processing 472 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00010.wav
# Processing 473 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00011.wav
# Processing 474 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00005.wav
# Processing 475 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00039.wav
# Processing 476 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00089.wav
# Processing 477 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00062.wav
# Processing 478 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00076.wav
# Processing 479 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00077.wav
# Processing 480 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00063.wav
# Processing 481 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00088.wav
# Processing 482 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00075.wav
# Processing 483 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00061.wav
# Processing 484 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00049.wav
# Processing 485 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00048.wav
# Processing 486 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00060.wav
# Processing 487 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00074.wav
# Processing 488 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00058.wav
# Processing 489 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00070.wav
# Processing 490 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00064.wav
# Processing 491 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00065.wav
# Processing 492 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00071.wav
# Processing 493 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00059.wav
# Processing 494 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00098.wav
# Processing 495 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00067.wav
# Processing 496 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00073.wav
# Processing 497 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00072.wav
# Processing 498 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00066.wav
# Processing 499 /Users/georgetzanetakis/data/sound/genres/reggae/reggae.00099.wav
# Processing 500 /Users/georgetzanetakis/data/sound/genres/classical/classical.00079.wav
# Processing 501 /Users/georgetzanetakis/data/sound/genres/classical/classical.00045.wav
# Processing 502 /Users/georgetzanetakis/data/sound/genres/classical/classical.00051.wav
# Processing 503 /Users/georgetzanetakis/data/sound/genres/classical/classical.00086.wav
# Processing 504 /Users/georgetzanetakis/data/sound/genres/classical/classical.00092.wav
# Processing 505 /Users/georgetzanetakis/data/sound/genres/classical/classical.00093.wav
# Processing 506 /Users/georgetzanetakis/data/sound/genres/classical/classical.00087.wav
# Processing 507 /Users/georgetzanetakis/data/sound/genres/classical/classical.00050.wav
# Processing 508 /Users/georgetzanetakis/data/sound/genres/classical/classical.00044.wav
# Processing 509 /Users/georgetzanetakis/data/sound/genres/classical/classical.00078.wav
# Processing 510 /Users/georgetzanetakis/data/sound/genres/classical/classical.00052.wav
# Processing 511 /Users/georgetzanetakis/data/sound/genres/classical/classical.00046.wav
# Processing 512 /Users/georgetzanetakis/data/sound/genres/classical/classical.00091.wav
# Processing 513 /Users/georgetzanetakis/data/sound/genres/classical/classical.00085.wav
# Processing 514 /Users/georgetzanetakis/data/sound/genres/classical/classical.00084.wav
# Processing 515 /Users/georgetzanetakis/data/sound/genres/classical/classical.00090.wav
# Processing 516 /Users/georgetzanetakis/data/sound/genres/classical/classical.00047.wav
# Processing 517 /Users/georgetzanetakis/data/sound/genres/classical/classical.00053.wav
# Processing 518 /Users/georgetzanetakis/data/sound/genres/classical/classical.00057.wav
# Processing 519 /Users/georgetzanetakis/data/sound/genres/classical/classical.00043.wav
# Processing 520 /Users/georgetzanetakis/data/sound/genres/classical/classical.00094.wav
# Processing 521 /Users/georgetzanetakis/data/sound/genres/classical/classical.00080.wav
# Processing 522 /Users/georgetzanetakis/data/sound/genres/classical/classical.00081.wav
# Processing 523 /Users/georgetzanetakis/data/sound/genres/classical/classical.00095.wav
# Processing 524 /Users/georgetzanetakis/data/sound/genres/classical/classical.00042.wav
# Processing 525 /Users/georgetzanetakis/data/sound/genres/classical/classical.00056.wav
# Processing 526 /Users/georgetzanetakis/data/sound/genres/classical/classical.00040.wav
# Processing 527 /Users/georgetzanetakis/data/sound/genres/classical/classical.00054.wav
# Processing 528 /Users/georgetzanetakis/data/sound/genres/classical/classical.00068.wav
# Processing 529 /Users/georgetzanetakis/data/sound/genres/classical/classical.00083.wav
# Processing 530 /Users/georgetzanetakis/data/sound/genres/classical/classical.00097.wav
# Processing 531 /Users/georgetzanetakis/data/sound/genres/classical/classical.00096.wav
# Processing 532 /Users/georgetzanetakis/data/sound/genres/classical/classical.00082.wav
# Processing 533 /Users/georgetzanetakis/data/sound/genres/classical/classical.00069.wav
# Processing 534 /Users/georgetzanetakis/data/sound/genres/classical/classical.00055.wav
# Processing 535 /Users/georgetzanetakis/data/sound/genres/classical/classical.00041.wav
# Processing 536 /Users/georgetzanetakis/data/sound/genres/classical/classical.00026.wav
# Processing 537 /Users/georgetzanetakis/data/sound/genres/classical/classical.00032.wav
# Processing 538 /Users/georgetzanetakis/data/sound/genres/classical/classical.00033.wav
# Processing 539 /Users/georgetzanetakis/data/sound/genres/classical/classical.00027.wav
# Processing 540 /Users/georgetzanetakis/data/sound/genres/classical/classical.00019.wav
# Processing 541 /Users/georgetzanetakis/data/sound/genres/classical/classical.00031.wav
# Processing 542 /Users/georgetzanetakis/data/sound/genres/classical/classical.00025.wav
# Processing 543 /Users/georgetzanetakis/data/sound/genres/classical/classical.00024.wav
# Processing 544 /Users/georgetzanetakis/data/sound/genres/classical/classical.00030.wav
# Processing 545 /Users/georgetzanetakis/data/sound/genres/classical/classical.00018.wav
# Processing 546 /Users/georgetzanetakis/data/sound/genres/classical/classical.00034.wav
# Processing 547 /Users/georgetzanetakis/data/sound/genres/classical/classical.00020.wav
# Processing 548 /Users/georgetzanetakis/data/sound/genres/classical/classical.00008.wav
# Processing 549 /Users/georgetzanetakis/data/sound/genres/classical/classical.00009.wav
# Processing 550 /Users/georgetzanetakis/data/sound/genres/classical/classical.00021.wav
# Processing 551 /Users/georgetzanetakis/data/sound/genres/classical/classical.00035.wav
# Processing 552 /Users/georgetzanetakis/data/sound/genres/classical/classical.00023.wav
# Processing 553 /Users/georgetzanetakis/data/sound/genres/classical/classical.00037.wav
# Processing 554 /Users/georgetzanetakis/data/sound/genres/classical/classical.00036.wav
# Processing 555 /Users/georgetzanetakis/data/sound/genres/classical/classical.00022.wav
# Processing 556 /Users/georgetzanetakis/data/sound/genres/classical/classical.00007.wav
# Processing 557 /Users/georgetzanetakis/data/sound/genres/classical/classical.00013.wav
# Processing 558 /Users/georgetzanetakis/data/sound/genres/classical/classical.00012.wav
# Processing 559 /Users/georgetzanetakis/data/sound/genres/classical/classical.00006.wav
# Processing 560 /Users/georgetzanetakis/data/sound/genres/classical/classical.00038.wav
# Processing 561 /Users/georgetzanetakis/data/sound/genres/classical/classical.00010.wav
# Processing 562 /Users/georgetzanetakis/data/sound/genres/classical/classical.00004.wav
# Processing 563 /Users/georgetzanetakis/data/sound/genres/classical/classical.00005.wav
# Processing 564 /Users/georgetzanetakis/data/sound/genres/classical/classical.00011.wav
# Processing 565 /Users/georgetzanetakis/data/sound/genres/classical/classical.00039.wav
# Processing 566 /Users/georgetzanetakis/data/sound/genres/classical/classical.00015.wav
# Processing 567 /Users/georgetzanetakis/data/sound/genres/classical/classical.00001.wav
# Processing 568 /Users/georgetzanetakis/data/sound/genres/classical/classical.00029.wav
# Processing 569 /Users/georgetzanetakis/data/sound/genres/classical/classical.00028.wav
# Processing 570 /Users/georgetzanetakis/data/sound/genres/classical/classical.00000.wav
# Processing 571 /Users/georgetzanetakis/data/sound/genres/classical/classical.00014.wav
# Processing 572 /Users/georgetzanetakis/data/sound/genres/classical/classical.00002.wav
# Processing 573 /Users/georgetzanetakis/data/sound/genres/classical/classical.00016.wav
# Processing 574 /Users/georgetzanetakis/data/sound/genres/classical/classical.00017.wav
# Processing 575 /Users/georgetzanetakis/data/sound/genres/classical/classical.00003.wav
# Processing 576 /Users/georgetzanetakis/data/sound/genres/classical/classical.00058.wav
# Processing 577 /Users/georgetzanetakis/data/sound/genres/classical/classical.00064.wav
# Processing 578 /Users/georgetzanetakis/data/sound/genres/classical/classical.00070.wav
# Processing 579 /Users/georgetzanetakis/data/sound/genres/classical/classical.00071.wav
# Processing 580 /Users/georgetzanetakis/data/sound/genres/classical/classical.00065.wav
# Processing 581 /Users/georgetzanetakis/data/sound/genres/classical/classical.00059.wav
# Processing 582 /Users/georgetzanetakis/data/sound/genres/classical/classical.00073.wav
# Processing 583 /Users/georgetzanetakis/data/sound/genres/classical/classical.00067.wav
# Processing 584 /Users/georgetzanetakis/data/sound/genres/classical/classical.00098.wav
# Processing 585 /Users/georgetzanetakis/data/sound/genres/classical/classical.00099.wav
# Processing 586 /Users/georgetzanetakis/data/sound/genres/classical/classical.00066.wav
# Processing 587 /Users/georgetzanetakis/data/sound/genres/classical/classical.00072.wav
# Processing 588 /Users/georgetzanetakis/data/sound/genres/classical/classical.00076.wav
# Processing 589 /Users/georgetzanetakis/data/sound/genres/classical/classical.00062.wav
# Processing 590 /Users/georgetzanetakis/data/sound/genres/classical/classical.00089.wav
# Processing 591 /Users/georgetzanetakis/data/sound/genres/classical/classical.00088.wav
# Processing 592 /Users/georgetzanetakis/data/sound/genres/classical/classical.00063.wav
# Processing 593 /Users/georgetzanetakis/data/sound/genres/classical/classical.00077.wav
# Processing 594 /Users/georgetzanetakis/data/sound/genres/classical/classical.00061.wav
# Processing 595 /Users/georgetzanetakis/data/sound/genres/classical/classical.00075.wav
# Processing 596 /Users/georgetzanetakis/data/sound/genres/classical/classical.00049.wav
# Processing 597 /Users/georgetzanetakis/data/sound/genres/classical/classical.00048.wav
# Processing 598 /Users/georgetzanetakis/data/sound/genres/classical/classical.00074.wav
# Processing 599 /Users/georgetzanetakis/data/sound/genres/classical/classical.00060.wav
# Processing 600 /Users/georgetzanetakis/data/sound/genres/rock/rock.00011.wav
# ...
# Processing 801 /Users/georgetzanetakis/data/sound/genres/country/country.00063.wav
# Processing 802 /Users/georgetzanetakis/data/sound/genres/country/country.00077.wav
# Processing 803 /Users/georgetzanetakis/data/sound/genres/country/country.00076.wav
# Processing 804 /Users/georgetzanetakis/data/sound/genres/country/country.00062.wav
# Processing 805 /Users/georgetzanetakis/data/sound/genres/country/country.00089.wav
# Processing 806 /Users/georgetzanetakis/data/sound/genres/country/country.00048.wav
# Processing 807 /Users/georgetzanetakis/data/sound/genres/country/country.00074.wav
# Processing 808 /Users/georgetzanetakis/data/sound/genres/country/country.00060.wav
# Processing 809 /Users/georgetzanetakis/data/sound/genres/country/country.00061.wav
# Processing 810 /Users/georgetzanetakis/data/sound/genres/country/country.00075.wav
# Processing 811 /Users/georgetzanetakis/data/sound/genres/country/country.00049.wav
# Processing 812 /Users/georgetzanetakis/data/sound/genres/country/country.00071.wav
# Processing 813 /Users/georgetzanetakis/data/sound/genres/country/country.00065.wav
# Processing 814 /Users/georgetzanetakis/data/sound/genres/country/country.00059.wav
# Processing 815 /Users/georgetzanetakis/data/sound/genres/country/country.00058.wav
# Processing 816 /Users/georgetzanetakis/data/sound/genres/country/country.00064.wav
# Processing 817 /Users/georgetzanetakis/data/sound/genres/country/country.00070.wav
# Processing 818 /Users/georgetzanetakis/data/sound/genres/country/country.00099.wav
# Processing 819 /Users/georgetzanetakis/data/sound/genres/country/country.00066.wav
# Processing 820 /Users/georgetzanetakis/data/sound/genres/country/country.00072.wav
# Processing 821 /Users/georgetzanetakis/data/sound/genres/country/country.00073.wav
# Processing 822 /Users/georgetzanetakis/data/sound/genres/country/country.00067.wav
# Processing 823 /Users/georgetzanetakis/data/sound/genres/country/country.00098.wav
# Processing 824 /Users/georgetzanetakis/data/sound/genres/country/country.00028.wav
# Processing 825 /Users/georgetzanetakis/data/sound/genres/country/country.00000.wav
# Processing 826 /Users/georgetzanetakis/data/sound/genres/country/country.00014.wav
# Processing 827 /Users/georgetzanetakis/data/sound/genres/country/country.00015.wav
# Processing 828 /Users/georgetzanetakis/data/sound/genres/country/country.00001.wav
# Processing 829 /Users/georgetzanetakis/data/sound/genres/country/country.00029.wav
# Processing 830 /Users/georgetzanetakis/data/sound/genres/country/country.00017.wav
# Processing 831 /Users/georgetzanetakis/data/sound/genres/country/country.00003.wav
# Processing 832 /Users/georgetzanetakis/data/sound/genres/country/country.00002.wav
# Processing 833 /Users/georgetzanetakis/data/sound/genres/country/country.00016.wav
# Processing 834 /Users/georgetzanetakis/data/sound/genres/country/country.00012.wav
# Processing 835 /Users/georgetzanetakis/data/sound/genres/country/country.00006.wav
# Processing 836 /Users/georgetzanetakis/data/sound/genres/country/country.00007.wav
# Processing 837 /Users/georgetzanetakis/data/sound/genres/country/country.00013.wav
# Processing 838 /Users/georgetzanetakis/data/sound/genres/country/country.00005.wav
# Processing 839 /Users/georgetzanetakis/data/sound/genres/country/country.00011.wav
# Processing 840 /Users/georgetzanetakis/data/sound/genres/country/country.00039.wav
# Processing 841 /Users/georgetzanetakis/data/sound/genres/country/country.00038.wav
# Processing 842 /Users/georgetzanetakis/data/sound/genres/country/country.00010.wav
# Processing 843 /Users/georgetzanetakis/data/sound/genres/country/country.00004.wav
# Processing 844 /Users/georgetzanetakis/data/sound/genres/country/country.00009.wav
# Processing 845 /Users/georgetzanetakis/data/sound/genres/country/country.00021.wav
# Processing 846 /Users/georgetzanetakis/data/sound/genres/country/country.00035.wav
# Processing 847 /Users/georgetzanetakis/data/sound/genres/country/country.00034.wav
# Processing 848 /Users/georgetzanetakis/data/sound/genres/country/country.00020.wav
# Processing 849 /Users/georgetzanetakis/data/sound/genres/country/country.00008.wav
# Processing 850 /Users/georgetzanetakis/data/sound/genres/country/country.00036.wav
# Processing 851 /Users/georgetzanetakis/data/sound/genres/country/country.00022.wav
# Processing 852 /Users/georgetzanetakis/data/sound/genres/country/country.00023.wav
# Processing 853 /Users/georgetzanetakis/data/sound/genres/country/country.00037.wav
# Processing 854 /Users/georgetzanetakis/data/sound/genres/country/country.00033.wav
# Processing 855 /Users/georgetzanetakis/data/sound/genres/country/country.00027.wav
# Processing 856 /Users/georgetzanetakis/data/sound/genres/country/country.00026.wav
# Processing 857 /Users/georgetzanetakis/data/sound/genres/country/country.00032.wav
# Processing 858 /Users/georgetzanetakis/data/sound/genres/country/country.00024.wav
# Processing 859 /Users/georgetzanetakis/data/sound/genres/country/country.00030.wav
# Processing 860 /Users/georgetzanetakis/data/sound/genres/country/country.00018.wav
# Processing 861 /Users/georgetzanetakis/data/sound/genres/country/country.00019.wav
# Processing 862 /Users/georgetzanetakis/data/sound/genres/country/country.00031.wav
# Processing 863 /Users/georgetzanetakis/data/sound/genres/country/country.00025.wav
# Processing 864 /Users/georgetzanetakis/data/sound/genres/country/country.00081.wav
# Processing 865 /Users/georgetzanetakis/data/sound/genres/country/country.00095.wav
# Processing 866 /Users/georgetzanetakis/data/sound/genres/country/country.00042.wav
# Processing 867 /Users/georgetzanetakis/data/sound/genres/country/country.00056.wav
# Processing 868 /Users/georgetzanetakis/data/sound/genres/country/country.00057.wav
# Processing 869 /Users/georgetzanetakis/data/sound/genres/country/country.00043.wav
# Processing 870 /Users/georgetzanetakis/data/sound/genres/country/country.00094.wav
# Processing 871 /Users/georgetzanetakis/data/sound/genres/country/country.00080.wav
# Processing 872 /Users/georgetzanetakis/data/sound/genres/country/country.00096.wav
# Processing 873 /Users/georgetzanetakis/data/sound/genres/country/country.00082.wav
# Processing 874 /Users/georgetzanetakis/data/sound/genres/country/country.00069.wav
# Processing 875 /Users/georgetzanetakis/data/sound/genres/country/country.00055.wav
# Processing 876 /Users/georgetzanetakis/data/sound/genres/country/country.00041.wav
# Processing 877 /Users/georgetzanetakis/data/sound/genres/country/country.00040.wav
# Processing 878 /Users/georgetzanetakis/data/sound/genres/country/country.00054.wav
# Processing 879 /Users/georgetzanetakis/data/sound/genres/country/country.00068.wav
# Processing 880 /Users/georgetzanetakis/data/sound/genres/country/country.00083.wav
# Processing 881 /Users/georgetzanetakis/data/sound/genres/country/country.00097.wav
# Processing 882 /Users/georgetzanetakis/data/sound/genres/country/country.00093.wav
# Processing 883 /Users/georgetzanetakis/data/sound/genres/country/country.00087.wav
# Processing 884 /Users/georgetzanetakis/data/sound/genres/country/country.00050.wav
# Processing 885 /Users/georgetzanetakis/data/sound/genres/country/country.00044.wav
# Processing 886 /Users/georgetzanetakis/data/sound/genres/country/country.00078.wav
# Processing 887 /Users/georgetzanetakis/data/sound/genres/country/country.00079.wav
# Processing 888 /Users/georgetzanetakis/data/sound/genres/country/country.00045.wav
# Processing 889 /Users/georgetzanetakis/data/sound/genres/country/country.00051.wav
# Processing 890 /Users/georgetzanetakis/data/sound/genres/country/country.00086.wav
# Processing 891 /Users/georgetzanetakis/data/sound/genres/country/country.00092.wav
# Processing 892 /Users/georgetzanetakis/data/sound/genres/country/country.00084.wav
# Processing 893 /Users/georgetzanetakis/data/sound/genres/country/country.00090.wav
# Processing 894 /Users/georgetzanetakis/data/sound/genres/country/country.00047.wav
# Processing 895 /Users/georgetzanetakis/data/sound/genres/country/country.00053.wav
# Processing 896 /Users/georgetzanetakis/data/sound/genres/country/country.00052.wav
# Processing 897 /Users/georgetzanetakis/data/sound/genres/country/country.00046.wav
# Processing 898 /Users/georgetzanetakis/data/sound/genres/country/country.00091.wav
# Processing 899 /Users/georgetzanetakis/data/sound/genres/country/country.00085.wav
# Processing 900 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00016.wav
# Processing 901 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00002.wav
# Processing 902 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00003.wav
# Processing 903 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00017.wav
# Processing 904 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00001.wav
# Processing 905 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00015.wav
# Processing 906 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00029.wav
# Processing 907 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00028.wav
# Processing 908 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00014.wav
# Processing 909 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00000.wav
# Processing 910 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00038.wav
# Processing 911 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00004.wav
# Processing 912 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00010.wav
# Processing 913 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00011.wav
# Processing 914 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00005.wav
# Processing 915 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00039.wav
# Processing 916 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00013.wav
# Processing 917 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00007.wav
# Processing 918 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00006.wav
# Processing 919 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00012.wav
# Processing 920 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00075.wav
# Processing 921 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00061.wav
# Processing 922 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00049.wav
# Processing 923 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00048.wav
# Processing 924 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00060.wav
# Processing 925 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00074.wav
# Processing 926 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00062.wav
# Processing 927 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00076.wav
# Processing 928 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00089.wav
# Processing 929 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00088.wav
# Processing 930 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00077.wav
# Processing 931 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00063.wav
# Processing 932 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00067.wav
# Processing 933 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00073.wav
# Processing 934 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00098.wav
# Processing 935 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00099.wav
# Processing 936 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00072.wav
# Processing 937 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00066.wav
# Processing 938 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00058.wav
# Processing 939 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00070.wav
# Processing 940 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00064.wav
# Processing 941 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00065.wav
# Processing 942 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00071.wav
# Processing 943 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00059.wav
# Processing 944 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00054.wav
# Processing 945 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00040.wav
# Processing 946 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00068.wav
# Processing 947 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00097.wav
# Processing 948 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00083.wav
# Processing 949 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00082.wav
# Processing 950 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00096.wav
# Processing 951 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00069.wav
# Processing 952 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00041.wav
# Processing 953 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00055.wav
# Processing 954 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00043.wav
# Processing 955 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00057.wav
# Processing 956 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00080.wav
# Processing 957 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00094.wav
# Processing 958 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00095.wav
# Processing 959 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00081.wav
# Processing 960 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00056.wav
# Processing 961 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00042.wav
# Processing 962 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00046.wav
# Processing 963 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00052.wav
# Processing 964 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00085.wav
# Processing 965 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00091.wav
# Processing 966 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00090.wav
# Processing 967 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00084.wav
# Processing 968 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00053.wav
# Processing 969 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00047.wav
# Processing 970 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00079.wav
# Processing 971 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00051.wav
# Processing 972 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00045.wav
# Processing 973 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00092.wav
# Processing 974 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00086.wav
# Processing 975 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00087.wav
# Processing 976 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00093.wav
# Processing 977 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00044.wav
# Processing 978 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00050.wav
# Processing 979 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00078.wav
# Processing 980 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00037.wav
# Processing 981 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00023.wav
# Processing 982 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00022.wav
# Processing 983 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00036.wav
# Processing 984 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00020.wav
# Processing 985 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00034.wav
# Processing 986 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00008.wav
# Processing 987 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00009.wav
# Processing 988 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00035.wav
# Processing 989 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00021.wav
# Processing 990 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00019.wav
# Processing 991 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00025.wav
# Processing 992 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00031.wav
# Processing 993 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00030.wav
# Processing 994 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00024.wav
# Processing 995 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00018.wav
# Processing 996 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00032.wav
# Processing 997 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00026.wav
# Processing 998 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00027.wav
# Processing 999 /Users/georgetzanetakis/data/sound/genres/jazz/jazz.00033.wav
# (1000, 40)

# %% [markdown]
# We can view the confusion matrix and classificaton report with micro and macro average retrieval metrics. You can observe from the confusion matrix that classical is the easiest genre to classify with 89/100 instances classified correctly. This is reflected on the corresponding f1-score of 0.89. Because the classes are balanced there is no difference between the macro and micro averaging.

# %%
from sklearn.model_selection import cross_val_predict
from sklearn import svm, metrics
clf = svm.SVC(gamma='scale', kernel='linear')

# perform 10-fold cross-validation to calculate accuracy and confusion matrix 
predicted = cross_val_predict(clf, audio_features, target, cv=10)

print("Confusion matrix:\n%s" % metrics.confusion_matrix(target, predicted))
print("Classification report for classifier %s:\n%s\n"
      % (clf, metrics.classification_report(target, predicted, target_names=genres)))
# Out:
# Confusion matrix:
# [[89  1  1  0  8  0  0  1  0  0]
#  [ 2 61  4  0  4  8 11  5  4  1]
#  [ 1  9 52  9  0 12  3  7  6  1]
#  [ 0  2  9 62  0  3  3 16  1  4]
#  [ 7  6  2  0 76  6  2  1  0  0]
#  [ 0  7 17  4  3 41 17  4  1  6]
#  [ 0 18  8  1  9  8 46  2  0  8]
#  [ 1  8  9 22  1  5  7 40  6  1]
#  [ 0  4 10  5  2  2  0  4 73  0]
#  [ 0  2  4  7  0  9  1  1  0 76]]
# Classification report for classifier SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#               precision    recall  f1-score   support
#
#    classical       0.89      0.89      0.89       100
#      country       0.52      0.61      0.56       100
#        disco       0.45      0.52      0.48       100
#       hiphop       0.56      0.62      0.59       100
#         jazz       0.74      0.76      0.75       100
#         rock       0.44      0.41      0.42       100
#        blues       0.51      0.46      0.48       100
#       reggae       0.49      0.40      0.44       100
#          pop       0.80      0.73      0.76       100
#        metal       0.78      0.76      0.77       100
#
#    micro avg       0.62      0.62      0.62      1000
#    macro avg       0.62      0.62      0.62      1000
# weighted avg       0.62      0.62      0.62      1000

# %%
# merge rock and pop to a single genre with more support (300 instances) than the other genres (100 instanes)
new_genres = ['classsical_jazz', 'country', 'disco', 'hiphop','rock','pop', 'blues','reggage', 'metal']
new_target = [0 if k==4 else k for k in target]
print(new_genres)
# Out:
# ['classsical_jazz', 'country', 'disco', 'hiphop', 'rock', 'pop', 'blues', 'reggage', 'metal']

# %%
# perform 10-fold cross-validation to calculate accuracy and confusion matrix 
predicted = cross_val_predict(clf, audio_features, new_target, cv=10)

print("Confusion matrix:\n%s" % metrics.confusion_matrix(target, predicted))
print("Classification report for classifier %s:\n%s\n"
      % (clf, metrics.classification_report(new_target, predicted, target_names=new_genres)))
# Out:
# Confusion matrix:
# [[95  1  1  0  0  1  0  2  0  0]
#  [ 7 59  3  0  0  9 11  6  4  1]
#  [ 2  8 52  9  0 12  3  7  6  1]
#  [ 0  2  9 62  0  3  3 16  1  4]
#  [83  5  2  0  0  5  4  1  0  0]
#  [ 7  6 17  4  0 36 17  4  3  6]
#  [ 6 15 10  1  0  8 48  5  0  7]
#  [ 2  7 10 23  0  4  7 40  6  1]
#  [ 2  4 10  5  0  2  0  4 73  0]
#  [ 0  2  4  7  0  9  1  1  0 76]]
# Classification report for classifier SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#                  precision    recall  f1-score   support
#
# classsical_jazz       0.87      0.89      0.88       200
#         country       0.54      0.59      0.56       100
#           disco       0.44      0.52      0.48       100
#          hiphop       0.56      0.62      0.59       100
#            rock       0.40      0.36      0.38       100
#             pop       0.51      0.48      0.49       100
#           blues       0.47      0.40      0.43       100
#         reggage       0.78      0.73      0.76       100
#           metal       0.79      0.76      0.78       100
#
#       micro avg       0.62      0.62      0.62      1000
#       macro avg       0.60      0.59      0.59      1000
#    weighted avg       0.62      0.62      0.62      1000

# %% [markdown]
# Notice that because of the unbalanced support of the different classes after merging classical and jazz the values of the micro-average f1-score and macro-average f1-score are different.

# %% [markdown]
# ## MIR tasks with time markers
#
# Finally let's look at a last usage of retrieval metrics (precision, recall and f-measure for tasks where the predicted output and the ground truth is a set of time markers corresponding to things like structure boundaries,
# beat locations, downbeats etc.
#
# In this case typically a time tolerance window is defined so that if a time marker is predicted near (within that window) a ground truth marker it is consider correct or relevant.
#
# One can easily see how over-segmemntation will affect precision. For example consider a predicted beat track output that is twice as fast as the ground truth. All the ground truth markers will be matched (recall will be 1)
# but only half of them will be correct (precision 0.5). Alternatively if the predicted beat track output is every two ground truth beats then the precision will be 1 (all the predicted beats are correct) but the recall will be 0.5 (half of the ground truth beat markers are predicted).
#
# Again the f1-score provides a balance between precision and recall. As an example if the marker detection depends on some parameters, we can perform a grid search over their values and select the one that provides the best f1-measure.
#
# Depending on the application domain we might be more interested in precision or recall. For example in a automatic video generation system for music that takes into account segmentation boundaries precision might be more important as we want to make sure that if a boundary is detected it is a true boundary with high probability. At the samne time we might not care as much about recall as if a boundary is missed occassionally the video will still look ok.

# %%
# Let's consider a simple toy example for calculating the retrieval metrics based on a time markers 
# To make things simple the tolerance is +/-1 i.e an estimated time marker is consider correct if it is 
# within +/-1 of the reference ground truth. 

import numpy as np

ref_times = np.array([0, 4, 8, 12, 16])
est_times = np.array([0, 9, 11, 18])


# precision is the number of "correct" estimated times divided by the number of estimates 
precision = 0 
for e in est_times: 
    diff = np.abs(e - ref_times)
    for d in diff: 
        if (d <= 1): 
            precision += 1
precision /= len(est_times)
print(precision)

# Note that the precision is 0.75 because the 4th estimated time marker - 18 is not part of the ground truth 


# recall is the percentage of the reference time markers that are returned as estimates 
recall = 0 
for r in ref_times:
    diff = np.abs(r - est_times)
    for d in diff: 
        if (d <=1): 
            recall += 1 
recall /= len(ref_times)
print(recall)

# Not that the recall is 0.6 because out of the 5 reference time markers only 3 are estimated correctly 
# (within +/-1 of a reference marker) |


def f1_score(precision, recall): 
    return 2 * ((precision * recall) / (precision+recall))

f1 = f1_score(precision,recall)
print("F1 = %.2f\n" % f1)
# Out:
# 0.75
# 0.6
# F1 = 0.67

# %%
def segment_metrics(ref_times, est_times): 
    precision = 0 
    for e in est_times: 
        diff = np.abs(e - ref_times)
        for d in diff: 
            if (d <= 1): 
                precision += 1
    precision /= len(est_times)
    
    recall = 0 
    for r in ref_times:
        diff = np.abs(r - est_times)
        for d in diff: 
            if (d <=1): 
                recall += 1 
    recall /= len(ref_times)
    f1_score = 2 * ((precision * recall) / (precision+recall))
    return (precision, recall, f1_score)

segment_metrics(ref_times, est_times)
# Out:
# (0.75, 0.6, 0.6666666666666665)

# %%
# high precision by undersegmentation 
ref_times = np.array([0, 4, 8, 12, 16])
est_times = np.array([9, 11])
segment_metrics(ref_times, est_times)
# Out:
# (1.0, 0.4, 0.5714285714285715)

# %%
# high recall by oversegmentation 
ref_times = np.array([0, 4, 8, 12, 16])
est_times = np.array([0,2,4,6,8,10,12,14,16])
segment_metrics(ref_times, est_times)
# Out:
# (0.5555555555555556, 1.0, 0.7142857142857143)

# %% [markdown]
# ## MIR tasks with pair-wise labels
#
# Another use of retrieval metrics is when there are cluster/segment labels per frame as in chord detection or structure segmentation. This evaluation combines information from the precision of the boundaries as well as ensuring that corrresponding segments are marked by the same label.
#
# The input consists of two sequences of labels (one corresponding to the reference ground truth and one
# corresponding to the estimated labels) using the same time granularity - typically frames or beats. The vocabulary of the labels can be different between the two segmentations. The retrieval metrics are computed over all possible pairs with a pair considered valid/correct/relevant if both items share a label.
