# %%
# !pip install music21
# !pip install pygame
# Out:
# Requirement already satisfied: music21 in c:\users\gtzan\miniconda3\lib\site-packages (9.1.0)
# Requirement already satisfied: chardet in c:\users\gtzan\miniconda3\lib\site-packages (from music21) (5.2.0)
# Requirement already satisfied: joblib in c:\users\gtzan\miniconda3\lib\site-packages (from music21) (1.3.2)
# Requirement already satisfied: jsonpickle in c:\users\gtzan\miniconda3\lib\site-packages (from music21) (3.0.2)
# Requirement already satisfied: matplotlib in c:\users\gtzan\miniconda3\lib\site-packages (from music21) (3.7.1)
# Requirement already satisfied: more-itertools in c:\users\gtzan\miniconda3\lib\site-packages (from music21) (10.2.0)
# Requirement already satisfied: numpy in c:\users\gtzan\miniconda3\lib\site-packages (from music21) (1.25.0)
# Requirement already satisfied: requests in c:\users\gtzan\miniconda3\lib\site-packages (from music21) (2.31.0)
# Requirement already satisfied: webcolors>=1.5 in c:\users\gtzan\miniconda3\lib\site-packages (from music21) (1.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gtzan\miniconda3\lib\site-packages (from matplotlib->music21) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\gtzan\miniconda3\lib\site-packages (from matplotlib->music21) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gtzan\miniconda3\lib\site-packages (from matplotlib->music21) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gtzan\miniconda3\lib\site-packages (from matplotlib->music21) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gtzan\miniconda3\lib\site-packages (from matplotlib->music21) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gtzan\miniconda3\lib\site-packages (from matplotlib->music21) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gtzan\miniconda3\lib\site-packages (from matplotlib->music21) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gtzan\miniconda3\lib\site-packages (from matplotlib->music21) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gtzan\miniconda3\lib\site-packages (from requests->music21) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gtzan\miniconda3\lib\site-packages (from requests->music21) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gtzan\miniconda3\lib\site-packages (from requests->music21) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gtzan\miniconda3\lib\site-packages (from requests->music21) (2023.5.7)
# Requirement already satisfied: six>=1.5 in c:\users\gtzan\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->music21) (1.16.0)
# Collecting pygame
#   Downloading pygame-2.5.2-cp311-cp311-win_amd64.whl (10.8 MB)
#                                               0.0/10.8 MB ? eta -:--:--
#                                               0.0/10.8 MB 1.3 MB/s eta 0:00:09
#                                               0.1/10.8 MB 1.1 MB/s eta 0:00:11
#                                               0.2/10.8 MB 1.5 MB/s eta 0:00:08
#      -                                        0.3/10.8 MB 1.8 MB/s eta 0:00:06
#      -                                        0.5/10.8 MB 2.3 MB/s eta 0:00:05
#      ---                                      1.0/10.8 MB 4.0 MB/s eta 0:00:03
#      -----                                    1.5/10.8 MB 4.7 MB/s eta 0:00:02
#      -------                                  2.1/10.8 MB 6.0 MB/s eta 0:00:02
#      --------                                 2.2/10.8 MB 5.4 MB/s eta 0:00:02
#      -----------                              3.2/10.8 MB 7.0 MB/s eta 0:00:02
#      ---------------                          4.1/10.8 MB 8.3 MB/s eta 0:00:01
#      -----------------                        4.8/10.8 MB 9.0 MB/s eta 0:00:01
#      --------------------                     5.5/10.8 MB 9.3 MB/s eta 0:00:01
#      ------------------------                 6.5/10.8 MB 10.1 MB/s eta 0:00:01
#      ----------------------------             7.6/10.8 MB 11.0 MB/s eta 0:00:01
#      --------------------------------         8.6/10.8 MB 11.7 MB/s eta 0:00:01
#      -----------------------------------      9.6/10.8 MB 12.3 MB/s eta 0:00:01
#      --------------------------------------  10.6/10.8 MB 16.0 MB/s eta 0:00:01
#      --------------------------------------- 10.8/10.8 MB 16.0 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.5.2

# %%
from music21 import *
us = environment.UserSettings()
print(us)
us['musicxmlPath'] = "C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe" 
us['musescoreDirectPNGPath'] = "C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe"
print(us)
# Out:
# {'directoryScratch': None, 'lilypondPath': 'C:\\Users\\gtzan\\Downloads\\mir_program_kadenze\\course1\\session3\\lilypond', 'lilypondVersion': None, 'lilypondFormat': 'pdf', 'lilypondBackend': 'ps', 'musicxmlPath': 'C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe', 'midiPath': None, 'graphicsPath': None, 'vectorPath': None, 'pdfPath': None, 'braillePath': None, 'musescoreDirectPNGPath': 'C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe', 'showFormat': 'musicxml', 'writeFormat': 'musicxml', 'ipythonShowFormat': 'ipython.musicxml.png', 'autoDownload': 'ask', 'debug': 0, 'warnings': 1, 'localCorpusSettings': LocalCorpusSettings([]), 'localCorporaSettings': {}, 'manualCoreCorpusPath': None}
# {'directoryScratch': None, 'lilypondPath': 'C:\\Users\\gtzan\\Downloads\\mir_program_kadenze\\course1\\session3\\lilypond', 'lilypondVersion': None, 'lilypondFormat': 'pdf', 'lilypondBackend': 'ps', 'musicxmlPath': 'C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe', 'midiPath': None, 'graphicsPath': None, 'vectorPath': None, 'pdfPath': None, 'braillePath': None, 'musescoreDirectPNGPath': 'C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe', 'showFormat': 'musicxml', 'writeFormat': 'musicxml', 'ipythonShowFormat': 'ipython.musicxml.png', 'autoDownload': 'ask', 'debug': 0, 'warnings': 1, 'localCorpusSettings': LocalCorpusSettings([]), 'localCorporaSettings': {}, 'manualCoreCorpusPath': None}

# %%
from music21 import *
us = environment.UserSettings()
print(us)
s = corpus.parse('bach/bwv65.2.xml')
s.show()
# Out:
# {'directoryScratch': None, 'lilypondPath': 'C:\\Users\\gtzan\\Downloads\\mir_program_kadenze\\course1\\session3\\lilypond', 'lilypondVersion': None, 'lilypondFormat': 'pdf', 'lilypondBackend': 'ps', 'musicxmlPath': 'C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe', 'midiPath': None, 'graphicsPath': None, 'vectorPath': None, 'pdfPath': None, 'braillePath': None, 'musescoreDirectPNGPath': 'C:\\Program Files\\MuseScore 4\\bin\\MuseScore4.exe', 'showFormat': 'musicxml', 'writeFormat': 'musicxml', 'ipythonShowFormat': 'ipython.musicxml.png', 'autoDownload': 'ask', 'debug': 0, 'warnings': 1, 'localCorpusSettings': LocalCorpusSettings([]), 'localCorporaSettings': {}, 'manualCoreCorpusPath': None}

# %%
sp = midi.realtime.StreamPlayer(s)
sp.play()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
